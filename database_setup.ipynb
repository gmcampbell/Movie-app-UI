# %% [markdown]
# ## Create .csv 'database' from movie title input

# %%
# Author Greg Campbell - see MIT License in repository
# Written with assistance from ChatGPT (GPT-5.2)
# Using OMDb API - see https://www.omdbapi.com/apikey.aspx for details and to get your free API key
# Note only 1000 requests per day for free key

# %%
# !pip install XlsxWriter
# !pip install requests
# !pip install streamlit

# %%
import requests
import csv
import time
import re

# %%
# ======================================
# CONFIGURATION
# ======================================

API_KEY = "YOUR_OMDB_API_KEY"       # TODO - Replace with your actual OMDb API key
INPUT_FILE = "Example_movies.txt"   # Replace with your list of movies (one title per line)
OUTPUT_FILE = "movie_database.csv"
REQUEST_DELAY = 0.1                 # seconds

# %%
# API Test
def test_api():
    url = f"http://www.omdbapi.com/?t=Inception&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    if data.get("Response") == "True":
        print("API Key is valid.")
    else:
        raise ValueError("API Key is invalid or there was an error. Update your API key and try again.")

# %%
# Testing API - make sure you set up your API key...
test_api()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Testing API - make sure you set up your API key...
# ----> 2 test_api()
#
# Cell In[17], line 9, in test_api()
#       7     print("API Key is valid.")
#       8 else:
# ----> 9     raise ValueError("API Key is invalid or there was an error. Update your API key and try again.")
#
# ValueError: API Key is invalid or there was an error. Update your API key and try again.

# %%
# ======================================
# HELPERS
# ======================================

def clean_title(title):
    return re.sub(r'[^a-z0-9]', '', title.lower())


def parse_title_and_year(raw_title):
    match = re.match(r"^(.*?)(?:\((\d{4})\))?$", raw_title.strip())
    title = match.group(1).strip()
    year = match.group(2) if match.group(2) else None
    return title, year


def is_imdb_id(value):
    return re.fullmatch(r"tt\d{7,8}", value.strip()) is not None


def expand_actors(movie_dict):
    actors_string = movie_dict.get("Actors", "")
    actors_list = [a.strip() for a in actors_string.split(",")]

    for i in range(10):
        key = f"Actor{i+1}"
        if i < len(actors_list):
            movie_dict[key] = actors_list[i]
        else:
            movie_dict[key] = ""

    return movie_dict


def validate_movie(detail_data, raw_title):
    # Runtime >= 30
    runtime_str = detail_data.get("Runtime", "").replace(" min", "")
    try:
        runtime = int(runtime_str)
        if runtime < 30:
            print(f"Skipping (too short): {raw_title}")
            return False
    except:
        print(f"Skipping (invalid runtime): {raw_title}")
        return False

    # Must have valid plot
    plot = detail_data.get("Plot", "").strip()
    if not plot or plot == "N/A":
        print(f"Skipping (no plot): {raw_title}")
        return False

    return True


# ======================================
# ROBUST FETCH
# ======================================

def fetch_movie_data(raw_input):
    base_url = "http://www.omdbapi.com/"
    raw_input = raw_input.strip()

    # ----------------------------------
    # CASE 1️⃣: IMDb ID Provided
    # ----------------------------------
    if is_imdb_id(raw_input):
        detail_params = {
            "apikey": API_KEY,
            "i": raw_input,
            "plot": "full"
        }

        response = requests.get(base_url, params=detail_params)
        detail_data = response.json()

        if detail_data.get("Response") == "False":
            print(f"Invalid IMDb ID: {raw_input}")
            return None

        if not validate_movie(detail_data, raw_input):
            return None

        return expand_actors(detail_data)

    # ----------------------------------
    # CASE 2️⃣: Title (with optional year)
    # ----------------------------------
    title, year = parse_title_and_year(raw_input)

    search_params = {
        "apikey": API_KEY,
        "s": title,
        "type": "movie"
    }

    search_response = requests.get(base_url, params=search_params)
    search_data = search_response.json()

    if search_data.get("Response") == "False":
        print(f"No search results: {raw_input}")
        return None

    results = search_data.get("Search", [])
    cleaned_input = clean_title(title)
    best_match = None

    for result in results:
        candidate_title = result.get("Title", "")
        cleaned_candidate = clean_title(candidate_title)

        if cleaned_candidate == cleaned_input:
            if year:
                if result.get("Year") == year:
                    best_match = result
                    break
            else:
                best_match = result
                break

    if not best_match:
        print(f"Using best guess for: {raw_input}")
        best_match = results[0]

    imdb_id = best_match["imdbID"]

    # Fetch full details
    detail_params = {
        "apikey": API_KEY,
        "i": imdb_id,
        "plot": "full"
    }

    detail_response = requests.get(base_url, params=detail_params)
    detail_data = detail_response.json()

    if detail_data.get("Response") == "False":
        print(f"Failed full fetch: {raw_input}")
        return None

    if not validate_movie(detail_data, raw_input):
        return None

    return expand_actors(detail_data)

# %% [markdown]
# ## Main - output will notify of any titles that failed to load
# #### Recommendation - import problem titles as IMDB ID's (search them on IMDB)

# %%
# ======================================
# MAIN
# ======================================

def main():
    with open(INPUT_FILE, "r", encoding="utf-8") as f:
        movie_inputs = [line.strip() for line in f if line.strip()]

    movie_data_list = []

    for entry in movie_inputs:
        # print(f"Processing: {entry}")
        data = fetch_movie_data(entry)

        if data:
            movie_data_list.append(data)

        time.sleep(REQUEST_DELAY)

    if not movie_data_list:
        print("No valid movie data collected.")
        return

    # Collect all keys
    all_keys = set()
    for movie in movie_data_list:
        all_keys.update(movie.keys())

    all_keys = sorted(all_keys)

    with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=all_keys)
        writer.writeheader()
        writer.writerows(movie_data_list)

    print(f"\n✅ Database saved to '{OUTPUT_FILE}'")


if __name__ == "__main__":
    main()
# Out:
# No search results: batman begins
# No search results: The Dark Knight
# No search results: the dark knight rises
# No search results: casino royale
# No search results: skyfall
# No search results: quantum of solace
# No search results: die another day
# No search results: octopussy
# No search results: moonraker
# No search results: Dr. No
# No search results: Tomorrow Never Dies
# No search results: You Only Live Twice
# No search results: Live and let die
# No search results: for your eyes Only
# No search results: goldeneye
# No search results: on her majesty's secret service
# No search results: from russia with love
# No search results: the man with the golden gun
# No search results: the world is not enough
# No search results: the living daylights
# No search results: goldfinger
# No search results: diamonds are forever
# No search results: Gamer
# No search results: Bedazzled
# No search results: Shrek
# No search results: Shrek 2
# No search results: The godfather
# No search results: the godfather part ii
# No search results: the godfather part iii
# No search results: my neighbor totoro
# No search results: ponyo
# No search results: kiki's delivery service
# No search results: castle in the sky
# No search results: sabrina
# No search results: breakfast at tiffany's
# No search results: roman holiday
# No search results: inside man
# No search results: i, robot
# No search results: safe house
# No search results: star trek
# No search results: wreck-it ralph
# No search results: 21 jump street
# No search results: V for Vendetta
# No search results: Flight
# No search results: the Hangover
# No search results: How to Train your Dragon
# Invalid IMDb ID: tt0462538
# No search results: the muppets
# No search results: space jam
# No search results: wedding crashers
# Invalid IMDb ID: tt0364725
# No search results: the princess Bride
# Invalid IMDb ID: tt1478338
# No search results: accepted
# No search results: our idiot brother
# No search results: super 8
# No search results: grown ups
# No search results: death race
# No search results: mean streets
# No search results: never say never again
# No search results: ghostbusters ii
# No search results: little fockers
# No search results: Paul
# No search results: I am number four
# No search results: Across the universe
# No search results: Antz
# No search results: Avatar
# No search results: the aviator
# No search results: away we go
# No search results: bedazzled
# No search results: the birds
# No search results: black swan
# No search results: blade runner
# No search results: catch me if you can
# No search results: cats don't dance
# No search results: chicago
# No search results: donnie darko
# No search results: the departed
# No search results: elysium
# No search results: erin brockovich
# No search results: the fifth element
# No search results: fight club
# No search results: forgetting sarah marshall
# No search results: gangster squad
# No search results: get out
# No search results: gone with the wind
# No search results: goodfellas
# No search results: the great gatsby
# No search results: guardians of the galaxy
# No search results: hidden figures
# No search results: i love you man
# No search results: josie and the pussycats
# No search results: Juno
# No search results: king kong
# No search results: kingsman the secret service
# No search results: labyrinth
# No search results: la la land
# Invalid IMDb ID: tt1707386
# No search results: the lion king
# Invalid IMDb ID: tt3281548
# No search results: mad max fury road
# No search results: moonrise kingdom
# No search results: napoleon dynamite
# No search results: the notebook
# No search results: the phantom of the opera
# Invalid IMDb ID: tt0395251
# No search results: psycho
# No search results: pulp fiction
# No search results: the revenant
# No search results: the rocky horror picture show
# No search results: saving private ryan
# No search results: se7en
# No search results: shutter island
# No search results: silver linings playbook
# No search results: spice world
# No search results: superbad
# No search results: sweeney todd the demon barber of fleet street
# No search results: Ted
# Invalid IMDb ID: tt0084787
# No search results: the town
# No search results: toy story
# No search results: trainwreck
# No search results: true grit
# No search results: walk the line
# No search results: westworld
# Invalid IMDb ID: tt0067992
# No search results: when harry met Sally
# No search results: wayne's world
# No search results: the wolf of wall street
# No search results: young frankenstein
# No search results: zero dark thirty
# No search results: zombieland
# Invalid IMDb ID: tt1306980
# No search results: 500 days of summer
# Invalid IMDb ID: tt3748528
# Invalid IMDb ID: tt2488496
# Invalid IMDb ID: tt2527336
# Invalid IMDb ID: tt0076759
# Invalid IMDb ID: tt0080684
# Invalid IMDb ID: tt0086190
# Invalid IMDb ID: tt0121766
# Invalid IMDb ID: tt0121765
# Invalid IMDb ID: tt0120915
# No search results: the lord of the rings the fellowship of the ring
# No search results: the lord of the rings the two towers
# No search results: the lord of the rings the return of the king
# No search results: fantastic beasts and where to find them
# Invalid IMDb ID: tt0241527
# Invalid IMDb ID: tt0295297
# Invalid IMDb ID: tt0304141
# Invalid IMDb ID: tt0330373
# Invalid IMDb ID: tt0373889
# Invalid IMDb ID: tt0417741
# Invalid IMDb ID: tt0926084
# Invalid IMDb ID: tt1201607
# No search results: Troy
# Invalid IMDb ID: tt0346491
# No search results: Jaws
# No search results: Hook
# No search results: Home for the Holidays
# No search results: Heathers
# No search results: Hannibal Rising
# No search results: Hannibal
# No search results: Groundhog day
# No search results: Good burger
# No search results: frozen
# Invalid IMDb ID: tt0109836
# No search results: doctor sleep
# No search results: despicable me
# No search results: clueless
# No search results: casablanca
# No search results: bring it on
# No search results: american hustle
# No search results: sideways
# No search results: the silence of the lambs
# No search results: the shining
# Invalid IMDb ID: tt0117509
# No search results: the patriot
# No search results: office space
# No search results: marie antoinette
# No search results: little miss sunshine
# No search results: the lego movie
# No valid movie data collected.

# %%
import pandas as pd

# %%
df = pd.read_csv(OUTPUT_FILE)
# sort by title
df = df.sort_values(by=["Title"])
df
# Out:
#                    Actor1  Actor10                Actor2           Actor3  \
# 0              Jonah Hill      NaN        Channing Tatum         Ice Cube
# 1    Joseph Gordon-Levitt      NaN            Seth Rogen    Anna Kendrick
# 2         Zooey Deschanel      NaN  Joseph Gordon-Levitt   Geoffrey Arend
# 3             Justin Long      NaN            Jonah Hill     Blake Lively
# 4        Evan Rachel Wood      NaN          Jim Sturgess     Joe Anderson
# ..                    ...      ...                   ...              ...
# 176        John C. Reilly      NaN         Jack McBrayer       Jane Lynch
# 177          Sean Connery      NaN     Akiko Wakabayashi         Mie Hama
# 178           Gene Wilder      NaN         Madeline Kahn    Marty Feldman
# 179      Jessica Chastain      NaN         Joel Edgerton      Chris Pratt
# 180       Jesse Eisenberg      NaN            Emma Stone  Woody Harrelson
#
#      Actor4  Actor5  Actor6  Actor7  Actor8  Actor9  ... Response  Runtime  \
# 0       NaN     NaN     NaN     NaN     NaN     NaN  ...     True  109 min
# 1       NaN     NaN     NaN     NaN     NaN     NaN  ...     True  100 min
# 2       NaN     NaN     NaN     NaN     NaN     NaN  ...     True   95 min
# 3       NaN     NaN     NaN     NaN     NaN     NaN  ...     True   93 min
# 4       NaN     NaN     NaN     NaN     NaN     NaN  ...     True  133 min
# ..      ...     ...     ...     ...     ...     ...  ...      ...      ...
# 176     NaN     NaN     NaN     NaN     NaN     NaN  ...     True  101 min
# 177     NaN     NaN     NaN     NaN     NaN     NaN  ...     True  117 min
# 178     NaN     NaN     NaN     NaN     NaN     NaN  ...     True  106 min
# 179     NaN     NaN     NaN     NaN     NaN     NaN  ...     True  157 min
# 180     NaN     NaN     NaN     NaN     NaN     NaN  ...     True   88 min
#
#                    Title   Type Website  \
# 0         21 Jump Street  movie     NaN
# 1                  50/50  movie     NaN
# 2     500 Days of Summer  movie     NaN
# 3               Accepted  movie     NaN
# 4    Across the Universe  movie     NaN
# ..                   ...    ...     ...
# 176       Wreck-It Ralph  movie     NaN
# 177  You Only Live Twice  movie     NaN
# 178   Young Frankenstein  movie     NaN
# 179     Zero Dark Thirty  movie     NaN
# 180           Zombieland  movie     NaN
#
#                                            Writer  Year     imdbID  \
# 0    Michael Bacall, Jonah Hill, Patrick Hasburgh  2012  tt1232829
# 1                                     Will Reiser  2011  tt1306980
# 2              Scott Neustadter, Michael H. Weber  2009  tt1022603
# 3           Mark Perez, Adam Cooper, Bill Collage  2006  tt0384793
# 4      Dick Clement, Ian La Frenais, Julie Taymor  2007  tt0445922
# ..                                            ...   ...        ...
# 176        Rich Moore, Phil Johnston, Jim Reardon  2012  tt1772341
# 177    Harold Jack Bloom, Roald Dahl, Ian Fleming  1967  tt0062512
# 178         Gene Wilder, Mel Brooks, Mary Shelley  1974  tt0072431
# 179                                     Mark Boal  2012  tt1790885
# 180                     Rhett Reese, Paul Wernick  2009  tt1156398
#
#      imdbRating imdbVotes
# 0           7.2   633,925
# 1           7.6   349,615
# 2           7.6   608,366
# 3           6.4   143,007
# 4           7.3   116,796
# ..          ...       ...
# 176         7.7   491,256
# 177         6.8   124,311
# 178         8.0   179,473
# 179         7.4   337,638
# 180         7.5   655,242
#
# [181 rows x 35 columns]
